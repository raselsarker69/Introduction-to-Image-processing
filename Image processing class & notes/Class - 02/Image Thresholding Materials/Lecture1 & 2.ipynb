# %% [markdown]
# ## Image Loading and Showing

# %% [markdown]
# ### MatplotLib

# %%
import matplotlib.pyplot as plt
image_path = '/content/drive/MyDrive/image_processing_innovative_skills/images/pexels-maxandrey-1366630.jpg'
image = plt.imread(image_path)

# %%
plt.imshow(image)

# %%
print(image)
# Out:
# [[[223 222 227]
#   [210 209 214]
#   [208 207 212]
#   ...
#   [216 216 218]
#   [217 217 219]
#   [223 223 225]]
#
#  [[226 225 230]
#   [213 212 217]
#   [209 208 213]
#   ...
#   [216 216 218]
#   [218 218 220]
#   [221 221 223]]
#
#  [[227 226 231]
#   [216 215 220]
#   [210 209 214]
#   ...
#   [221 221 223]
#   [223 223 225]
#   [222 222 224]]
#
#  ...
#
#  [[  0  16  10]
#   [  4  21  15]
#   [  5  22  16]
#   ...
#   [ 22  44  31]
#   [ 18  40  27]
#   [ 10  32  19]]
#
#  [[  0  13   7]
#   [  3  20  14]
#   [  5  22  16]
#   ...
#   [ 29  51  38]
#   [ 21  43  30]
#   [ 10  32  19]]
#
#  [[  8  25  19]
#   [ 15  32  26]
#   [ 14  31  25]
#   ...
#   [ 41  63  50]
#   [ 32  54  41]
#   [ 18  40  27]]]

# %%
print(image.shape)
# Out:
# (6000, 4000, 3)

# %% [markdown]
# ### OpenCV

# %%
import cv2
from matplotlib import pyplot as plt

# Load an image
image_path = '/content/drive/MyDrive/image_processing_innovative_skills/images/pexels-maxandrey-1366630.jpg'  # Use your image path
image = cv2.imread(image_path) # loading image using openCV

# Display the image
plt.imshow(image) # showing image uisng matplotlib
# plt.axis('off')  # Hide axes
# plt.show()

# %% [markdown]
# **Why the image looks different?**
#
# OpenCV uses BGR image format. So, when we read an image using cv2. imread() it interprets in BGR format by default.
#
# **OpenCV loads image in BGR and we are plotting RGB Image**
#
# **So we need to convert the BGR to RGB**

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # converting BGR to RGB
plt.imshow(image_rgb)

# %% [markdown]
# ### PIL

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load an image
image_path = '/content/drive/MyDrive/image_processing_innovative_skills/images/pexels-maxandrey-1366630.jpg'  # Upload your image to Colab
image = Image.open(image_path)

# Display the image
# image.show() # works only in local env
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# ### Color channel

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/pexels-maxandrey-1366630.jpg')

blue, green, red = cv2.split(image)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(6, 10))

plt.subplot(2, 2, 1)
plt.imshow(rgb)
plt.title('RGB Image')

plt.subplot(2, 2, 2)
plt.imshow(blue, cmap='gray')
plt.title('Blue Channel')

plt.subplot(2, 2, 3)
plt.imshow(green, cmap='gray')
plt.title('Green Channel')

plt.subplot(2, 2, 4)
plt.imshow(red, cmap='gray')
plt.title('Red Channel')
# Out:
# Text(0.5, 1.0, 'Red Channel')

# %% [markdown]
# ## ColorSpace conversion

# %%
# Matplotlib is usually pre-installed in Colab, but you can install it if needed
# !pip install matplotlib

import matplotlib.pyplot as plt
import numpy as np
import cv2

# Load an image
image_path = '/content/drive/MyDrive/image_processing_innovative_skills/images/pexels-maxandrey-1366630.jpg'  # Upload your image to Colab
image = cv2.imread(image_path)

# Convert BGR to Grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Convert BGR to HSV
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Display the images
plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title('Grayscale Image')

plt.subplot(1, 3, 3)
plt.imshow(hsv_image)
plt.axis('off')
plt.title('HSV Image')

plt.show()

# %% [markdown]
# ## Image Thresholding (Global)

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img = cv.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/orange-1.jpg', cv.IMREAD_GRAYSCALE)

# cv.threshold(gray_img, threshold_val, max_val, threshold_type)

# ret,thresh1 = cv.threshold(img, 190,255, cv.THRESH_BINARY)
ret,thresh1 = cv.threshold(img, 127,255, cv.THRESH_BINARY)
ret,thresh2 = cv.threshold(img, 127,255, cv.THRESH_BINARY_INV)

ret,thresh3 = cv.threshold(img, 127,255, cv.THRESH_TRUNC) # >threshold = threshold; <= unchanged
ret,thresh4 = cv.threshold(img, 127,255, cv.THRESH_TOZERO) # >threshold unchanged; <= 0(black);
ret,thresh5 = cv.threshold(img, 127,255, cv.THRESH_TOZERO_INV) # >threshold = 0(black); <= unchanged

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()
