# %% [markdown]
# ### Filtering

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
arr = [
    [1,1,1],
    [1,1,1],
    [1,1,1]
    ]
kernel = np.array(arr, dtype=np.float32)
print(kernel)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
kernel = np.ones((3,3), np.float32)
print(kernel)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]
#  [1. 1. 1.]]

# %%
kernel = kernel/9
print(kernel)
# Out:
# [[0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]
#  [0.11111111 0.11111111 0.11111111]]

# %%
# using filter2d

img = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/orange-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
assert img is not None, "file could not be read, check with os.path.exists()"

kernel1 = np.ones((3,3),np.float32)/9
blur_img1 = cv2.filter2D(img,-1,kernel1) # when ddepth=-1, the output image will have the same depth as the source.

kernel2 = np.ones((7,7),np.float32)/49
blur_img2 = cv2.filter2D(img,-1,kernel2)

plt.figure(figsize=(15, 5))

plt.subplot(131),plt.imshow(img),plt.title('Original')
plt.axis('off')
plt.subplot(132),plt.imshow(blur_img1),plt.title('Averaging 3X3')
plt.axis('off')
plt.subplot(133),plt.imshow(blur_img2),plt.title('Averaging 5X5')
plt.axis('off')
plt.show()

# %%
# using cv2.blur(img, (k,k))


img = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/orange-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
assert img is not None, "file could not be read, check with os.path.exists()"

blur_img1 = cv2.blur(img, (3, 3))

blur_img2 = cv2.blur(img, (5, 5))

plt.figure(figsize=(15, 5))

plt.subplot(131),plt.imshow(img),plt.title('Original')
plt.axis('off')
plt.subplot(132),plt.imshow(blur_img1),plt.title('Averaging 3X3')
plt.axis('off')
plt.subplot(133),plt.imshow(blur_img2),plt.title('Averaging 5X5')
plt.axis('off')
plt.show()

# %%
# other blur

img = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/berry-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
assert img is not None, "file could not be read, check with os.path.exists()"

avg_blur = cv2.blur(img, (5,5))
gaussian_blur = blur = cv.GaussianBlur(img,(5,5),0) # std=0 mean openCV will automatically
median_blur = cv.medianBlur(img, 5)
bilateral_blur = cv.bilateralFilter(img, 5, 75, 75)


plt.figure(figsize=(15, 5))

plt.subplot(141)
plt.imshow(avg_blur, cmap='gray')
plt.title('Averaging')
plt.axis('off')

plt.subplot(142)
plt.imshow(gaussian_blur, cmap='gray')
plt.title('Gaussian')
plt.axis('off')

plt.subplot(143)
plt.imshow(median_blur, cmap='gray')
plt.title('Median')
plt.axis('off')

plt.subplot(144)
plt.imshow(bilateral_blur, cmap='gray')
plt.title('Bilateral')
plt.axis('off')

plt.show()

# %%
# bilateral filter

img = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/berry-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
assert img is not None, "file could not be read, check with os.path.exists()"


bilateral_blur1 = cv2.bilateralFilter(img, 5, 25, 25)
bilateral_blur2 = cv2.bilateralFilter(img, 5, 250, 25)
bilateral_blur3 = cv2.bilateralFilter(img, 5, 50, 25)
bilateral_blur4 = cv2.bilateralFilter(img, 5, 75, 25)

plt.figure(figsize=(15, 5))

plt.subplot(141)
plt.imshow(bilateral_blur1, cmap='gray')
plt.title('Bilateral_filter1')
plt.axis('off')

plt.subplot(142)
plt.imshow(bilateral_blur2, cmap='gray')
plt.title('Bilateral_filter2')
plt.axis('off')

plt.subplot(143)
plt.imshow(bilateral_blur3, cmap='gray')
plt.title('Bilateral_filter3')
plt.axis('off')

plt.subplot(144)
plt.imshow(bilateral_blur4, cmap='gray')
plt.title('Bilateral_filter4')
plt.axis('off')

plt.show()

# %%
# bilateral filter

img = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/berry-1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
assert img is not None, "file could not be read, check with os.path.exists()"


bilateral_blur1 = cv2.bilateralFilter(img, 5, 100, 25)
bilateral_blur2 = cv2.bilateralFilter(img, 5, 100, 100)
bilateral_blur3 = cv2.bilateralFilter(img, 5, 100, 175)
bilateral_blur4 = cv2.bilateralFilter(img, 5, 100, 250)

plt.figure(figsize=(15, 5))

plt.subplot(141)
plt.imshow(bilateral_blur1, cmap='gray')
plt.title('Bilateral_filter1')
plt.axis('off')

plt.subplot(142)
plt.imshow(bilateral_blur2, cmap='gray')
plt.title('Bilateral_filter2')
plt.axis('off')

plt.subplot(143)
plt.imshow(bilateral_blur3, cmap='gray')
plt.title('Bilateral_filter3')
plt.axis('off')

plt.subplot(144)
plt.imshow(bilateral_blur4, cmap='gray')
plt.title('Bilateral_filter4')
plt.axis('off')

plt.show()

# %%
plt.imshow(img, cmap='gray')

# %%
arr1 = [
    [1,0,1],
    [1,0,1],
    [1,0,1]
    ]
kernel1 = np.array(arr1, dtype=np.float32)

arr2 = [
    [1,1,1],
    [0,0,0],
    [1,1,1]
    ]
kernel2 = np.array(arr2, dtype=np.float32)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# using filter2d

arr1 = [
    [1,0,1],
    [1,0,1],
    [1,0,1]
    ]
kernel1 = np.array(arr1, dtype=np.float32)
# kernel1 /= np.sum(kernel1)  # Normalize kernel1

arr2 = [
    [1,1,1],
    [0,0,0],
    [1,1,1]
    ]
kernel2 = np.array(arr2, dtype=np.float32)
# kernel2 /= np.sum(kernel2)  # Normalize kernel1

img = cv2.imread('/content/drive/MyDrive/image_processing_innovative_skills/images/circle_bw.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img.shape)
assert img is not None, "file could not be read, check with os.path.exists()"

blur_img1 = cv2.filter2D(img,-1,kernel1)

blur_img2 = cv2.filter2D(img,-1,kernel2)

plt.figure(figsize=(25, 5))

plt.subplot(131),plt.imshow(img, cmap='gray'),plt.title('Original')
plt.axis('off')
plt.subplot(132),plt.imshow(blur_img1, cmap='gray'),plt.title('Custom 3x3 var')
plt.axis('off')
plt.subplot(133),plt.imshow(blur_img2, cmap='gray'),plt.title('Custom 3x3 hor')
plt.axis('off')
plt.show()
# Out:
# (438, 498)
