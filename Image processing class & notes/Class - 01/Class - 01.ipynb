# %% [markdown]
# # Image Loding and showing using Matplotlib

# %%
import matplotlib.pyplot as plt 
from skimage import io
from PIL import Image
import numpy as np 
import cv2

# %%
# image loading.
image_path = 'flower.jpg'

# Load image
image = plt.imread(image_path)


plt.imshow(image)  # Display image
#plt.axis('off')  # hide axes
plt.show()

# %% [markdown]
# # Imag loard korbo Opencv diya and show korabo Matplotlib diya.

# %%
import cv2
image_path = 'flower.jpg'

# Load image
image = cv2.imread(image_path)


plt.imshow(image)  # Display image
#plt.axis('off')  # hide axes
plt.show()

# %%
print(image.shape)
# Out:
# (2000, 3008, 3)

# %%
print(image)
# Out:
# [[[ 5 13  6]
#   [ 5 13  6]
#   [ 5 13  6]
#   ...
#   [19 63 34]
#   [21 65 36]
#   [25 69 40]]
#
#  [[ 5 13  6]
#   [ 5 13  6]
#   [ 5 13  6]
#   ...
#   [18 62 33]
#   [20 64 35]
#   [23 67 38]]
#
#  [[ 5 13  6]
#   [ 5 13  6]
#   [ 5 13  6]
#   ...
#   [17 61 32]
#   [19 63 34]
#   [22 66 37]]
#
#  ...
#
#  [[24 55 28]
#   [28 59 32]
#   [31 62 35]
#   ...
#   [ 5 13  6]
#   [ 5 13  6]
#   [ 5 13  6]]
#
#  [[21 52 25]
#   [25 56 29]
#   [30 61 34]
#   ...
#   [ 4 12  5]
#   [ 4 12  5]
#   [ 4 12  5]]
#
#  [[14 45 18]
#   [19 50 23]
#   [25 56 29]
#   ...
#   [ 3 11  4]
#   [ 2 10  3]
#   [ 2 10  3]]]

# %% [markdown]
# Why does the image look different?
#
# OpenCV uses BGR format, so when we read an image using cv2.imread() interrupts BGR format by default, opencv image in BGR and we are floating RGB image so we need to convert the BGR to RGB format.

# %% [markdown]
# # Color space conversion BGR TO RGB

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.imshow('RGB Image',image_rgb )

# %%
image = cv2.imread('flower.jpg')

blue, green, red = cv2.split(image)

rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(6, 10))

plt.subplot(2, 2, 1)
plt.imshow(rgb)
plt.title('RGB Image')

plt.subplot(2, 2, 2)
plt.imshow(blue, cmap='gray')
plt.title('blue channel')

plt.subplot(2, 2, 3)
plt.imshow(green, cmap='gray')
plt.title('green channel')

plt.subplot(2, 2, 4)
plt.imshow(red, cmap='gray')
plt.title('red channel')
# Out:
# Text(0.5, 1.0, 'red channel')

# %% [markdown]
# # PIL(Pillow)

# %%
from PIL import Image
import matplotlib.pyplot as plt 

image_path = 'flower.jpg'

# Load image
image = Image.open(image_path)


plt.imshow(image)  # Display image
#plt.axis('off')  # hide axes
plt.show()

# %%
from skimage import io

image_path = 'flower.jpg'

# Load image using skimage
image_skimage = io.imread(image_path)

# Display the image
plt.imshow(image_skimage)
plt.axis('off')
plt.show()

print("Image shape:", image_skimage.shape)
# Out:
# skimage image shape: (2000, 3008, 3)

# %% [markdown]
# Explain the reason of color difference when an image is loaded with openCV but plotted using matplotlib.
#
# The color difference when loading an image with OpenCV and displaying it with Matplotlib occurs because,,,,,,
#
# OpenCV: loads images in BGR format, meaning that the first channel is blue, the second is green, and the third is red.
# Matplotlib: on the other hand, expects images in RGB format, where the first channel is red, the second is green, and the third is blue.
# Because the library controls two different color channels by default, that's the main reason for the difference in color.

# %%
plt.figure(figsize=(6, 10))

plt.subplot(2, 2, 1)
plt.imshow(rgb)
plt.title('RGB Image')

plt.subplot(2, 2, 2)
plt.imshow(blue, cmap='gray')
plt.title('blue channel')

plt.subplot(2, 2, 3)
plt.imshow(green, cmap='gray')
plt.title('green channel')

plt.subplot(2, 2, 4)
plt.imshow(red, cmap='gray')
plt.title('red channel')
# Out:
# Text(0.5, 1.0, 'red channel')

# %%
import matplotlib.pyplot as plt
import cv2

# Paths to the images
image_path1 = 'flower.jpg'
image_path2 = 'flower.jpg'
image_path3 = 'flower.jpg'

# Load images using OpenCV
image1 = cv2.imread(image_path1)
image2 = cv2.imread(image_path2)
image3 = cv2.imread(image_path3)

# Convert from BGR to RGB for correct display
image1_rgb = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2_rgb = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
image3_rgb = cv2.cvtColor(image3, cv2.COLOR_BGR2RGB)

# Create a figure
fig, axes = plt.subplots(3, 1, figsize=(5, 15))  # 3 rows, 1 column

# Plot image in a different subplot
axes[0].imshow(image1_rgb)
axes[0].axis('off')  

axes[1].imshow(image2_rgb)
axes[1].axis('off')

axes[2].imshow(image3_rgb)
axes[2].axis('off')

# Show the figure
plt.show()
